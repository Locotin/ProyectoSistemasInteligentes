# %%
import torch
import torchvision.models as models

# Cargar modelo ResNet-34 preentrenado
resnet34 = models.resnet34(pretrained=True)

# Mostrar la arquitectura del modelo
print(resnet34)
# Out:
# /home/angel/Documentos/ProyectoSistemasInteligentes/sisisvenv/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/angel/Documentos/ProyectoSistemasInteligentes/sisisvenv/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# ...

# %%
from PIL import Image
import numpy as np
import random
import os

# Seleccionar una imagen aleatoria del dataset
random_image = random.choice(image_files)
image_path = os.path.join(dataset_path, random_image)

# Cargar la imagen
image = Image.open(image_path)

# Mostrar detalles de la imagen
print(f"Imagen de prueba: {image_path}")
print(f"Formato: {image.format}")
print(f"Tamaño: {image.size}")  # (Ancho, Alto)
print(f"Modo de color: {image.mode}")  # RGB, Grayscale, etc.

# Convertir a numpy y mostrar valores de pixel
image_array = np.array(image)
print(f"Valores de píxeles: min {image_array.min()}, max {image_array.max()}")

# Mostrar imagen
image.show()
# Out:
# Ejemplo de archivos en la carpeta:
# ['99797_6.tif', '99856_7.tif', '99845_19.tif', '99795_23.tif', '99788_25.tif', '99853_15.tif', '99852_28.tif', '99804_13.tif', '99815_17.tif', '99834_24.tif']
# ✅ Se encontraron 2394 imágenes en la carpeta.
# Ejemplo de nombres de archivo: ['99797_6.tif', '99856_7.tif', '99845_19.tif', '99795_23.tif', '99788_25.tif']
